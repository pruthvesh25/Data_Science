# %%
# one hot encoding (input feature)

# %%
import pandas as pd

# %%
df = pd.read_csv('airports.csv')

# %%
df
# Out:
#      airport_id          city state                                 name
# 0         10165   Adak Island    AK                                 Adak
# 1         10299     Anchorage    AK  Ted Stevens Anchorage International
# 2         10304         Aniak    AK                        Aniak Airport
# 3         10754        Barrow    AK      Wiley Post/Will Rogers Memorial
# 4         10551        Bethel    AK                       Bethel Airport
# ..          ...           ...   ...                                  ...
# 360       11233      Cheyenne    WY  Cheyenne Regional/Jerry Olson Field
# 361       11097          Cody    WY                 Yellowstone Regional
# 362       11865      Gillette    WY             Gillette Campbell County
# 363       12441       Jackson    WY                         Jackson Hole
# 364       14543  Rock Springs    WY       Rock Springs Sweetwater County
#
# [365 rows x 4 columns]

# %%
# this how we find the frequency of unique columns in a dataset coulmn .

# %%
df['city'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Adak Island
# 1         Anchorage
# 2             Aniak
# 3            Barrow
# 4            Bethel
#            ...
# 360        Cheyenne
# 361            Cody
# 362        Gillette
# 363         Jackson
# 364    Rock Springs
# Name: city, Length: 365, dtype: object>

# %%
pd.get_dummies(df,columns=['city'])
# Out:
#      airport_id state                                 name  city_Aberdeen  \
# 0         10165    AK                                 Adak          False
# 1         10299    AK  Ted Stevens Anchorage International          False
# 2         10304    AK                        Aniak Airport          False
# 3         10754    AK      Wiley Post/Will Rogers Memorial          False
# 4         10551    AK                       Bethel Airport          False
# ..          ...   ...                                  ...            ...
# 360       11233    WY  Cheyenne Regional/Jerry Olson Field          False
# 361       11097    WY                 Yellowstone Regional          False
# 362       11865    WY             Gillette Campbell County          False
# 363       12441    WY                         Jackson Hole          False
# 364       14543    WY       Rock Springs Sweetwater County          False
#
#      city_Abilene  city_Adak Island  city_Aguadilla  city_Akron  city_Albany  \
# ...

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
li = LabelEncoder()

# %%
# used to encode the value via label encoding 

df['variety']=li.fit_transform(df['variety'])

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

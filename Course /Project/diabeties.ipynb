# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.shape
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# 0 - non diabetic 
#  - diabetic

# %%
x = df.drop(columns='Outcome',axis=1)
y = df['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# standerdization

# %%
scaler = StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(x)

# %%
standardized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
x = standardized_data

# %%
x
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train , x_test ,  y_train , y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (614, 8)

# %%
clf = svm.SVC(kernel='linear')

# %%
clf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
x_train_predict = clf.predict(x_train)

# %%
accuracy_score(x_train_predict,y_train)
# Out:
# 0.7638436482084691

# %%
# for test data

# %%
x_test_predict = clf.predict(x_test)
accuracy_score(x_test_predict,y_test)
# Out:
# 0.7922077922077922

# %%
for i in range(114):
    if(x_test_predict[i]==0):
        print("Person",i+1," is not diabetic")
    else:
        print("Person ",i+1," is diabetic")
# Out:
# Person  1  is diabetic
# Person 2  is not diabetic
# Person 3  is not diabetic
# Person  4  is diabetic
# Person 5  is not diabetic
# Person  6  is diabetic
# Person 7  is not diabetic
# Person 8  is not diabetic
# Person 9  is not diabetic
# Person 10  is not diabetic
# Person  11  is diabetic
# Person  12  is diabetic
# Person 13  is not diabetic
# Person 14  is not diabetic
# Person  15  is diabetic
# Person 16  is not diabetic
# Person 17  is not diabetic
# Person  18  is diabetic
# Person 19  is not diabetic
# Person 20  is not diabetic
# Person 21  is not diabetic
# Person 22  is not diabetic
# Person 23  is not diabetic
# Person 24  is not diabetic
# Person  25  is diabetic
# Person 26  is not diabetic
# Person 27  is not diabetic
# Person  28  is diabetic
# Person 29  is not diabetic
# Person 30  is not diabetic
# Person  31  is diabetic
# Person 32  is not diabetic
# Person 33  is not diabetic
# Person  34  is diabetic
# Person 35  is not diabetic
# Person 36  is not diabetic
# Person  37  is diabetic
# Person 38  is not diabetic
# Person 39  is not diabetic
# Person 40  is not diabetic
# Person  41  is diabetic
# Person 42  is not diabetic
# Person  43  is diabetic
# Person 44  is not diabetic
# Person  45  is diabetic
# Person 46  is not diabetic
# Person  47  is diabetic
# Person 48  is not diabetic
# Person 49  is not diabetic
# Person 50  is not diabetic
# Person  51  is diabetic
# Person 52  is not diabetic
# Person  53  is diabetic
# Person 54  is not diabetic
# Person 55  is not diabetic
# Person 56  is not diabetic
# Person  57  is diabetic
# Person 58  is not diabetic
# Person  59  is diabetic
# Person 60  is not diabetic
# Person 61  is not diabetic
# Person 62  is not diabetic
# Person 63  is not diabetic
# Person  64  is diabetic
# Person 65  is not diabetic
# Person 66  is not diabetic
# Person  67  is diabetic
# Person  68  is diabetic
# Person 69  is not diabetic
# Person 70  is not diabetic
# Person 71  is not diabetic
# Person 72  is not diabetic
# Person 73  is not diabetic
# Person 74  is not diabetic
# Person 75  is not diabetic
# Person 76  is not diabetic
# Person 77  is not diabetic
# Person 78  is not diabetic
# Person  79  is diabetic
# Person 80  is not diabetic
# Person 81  is not diabetic
# Person 82  is not diabetic
# Person  83  is diabetic
# Person  84  is diabetic
# Person 85  is not diabetic
# Person  86  is diabetic
# Person 87  is not diabetic
# Person 88  is not diabetic
# Person  89  is diabetic
# Person  90  is diabetic
# Person 91  is not diabetic
# Person 92  is not diabetic
# Person 93  is not diabetic
# Person 94  is not diabetic
# Person  95  is diabetic
# Person 96  is not diabetic
# Person  97  is diabetic
# Person 98  is not diabetic
# Person 99  is not diabetic
# Person 100  is not diabetic
# Person 101  is not diabetic
# Person 102  is not diabetic
# Person 103  is not diabetic
# Person 104  is not diabetic
# Person  105  is diabetic
# Person 106  is not diabetic
# Person 107  is not diabetic
# Person 108  is not diabetic
# Person 109  is not diabetic
# Person 110  is not diabetic
# Person  111  is diabetic
# Person 112  is not diabetic
# Person 113  is not diabetic
# Person 114  is not diabetic

# %%
# example with normal array

# %%
input_sample = (5,166,72,19,175,22.7,0.6,51)

# %%
input_np_array = np.array(input_sample)

# %%
# reshape array for one instance 
input_np_array = input_np_array.reshape(1,-1)

# %%
input_np_array
# Out:
# array([[  5. , 166. ,  72. ,  19. , 175. ,  22.7,   0.6,  51. ]])

# %%
std_data = scaler.transform(input_np_array)
# Out:
# /Users/pruthveshbaitule25/miniconda3/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
std_data
# Out:
# array([[ 0.3429808 ,  1.41167241,  0.14964075, -0.09637905,  0.82661621,
#         -1.179407  ,  0.38694877,  1.51108316]])

# %%
prediction = clf.predict(std_data)

# %%
prediction
# Out:
# array([1])

# %%
if(prediction[0]==0):
    print("Person is not diabetic")
else:
    print("Person is diabetic")
# Out:
# Person is diabetic

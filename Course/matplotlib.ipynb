# %%
import  matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([0,6])
y = np.array([0,80])

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# # dotted and normal graph

# %%
points = np.array([4,7,2,10,13])
plt.plot(points)
plt.show()

# %%
a2 =np.array([1,2,3,4,5,6])

# %%
plt.plot(a2 , linestyle = 'dotted')

# %% [markdown]
# # bar chart

# %%
x = np.array(["X","Y","Z","W"])
y = np.array([25,30,27,22])

# %%
plt.bar(x,y)
plt.show()

# %%
x1 = np.array([20,15,16,17,18])
y1 = np.array([12,56,12,45,12])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # pie chart

# %%
plt.pie(points)
plt.show()

# %% [markdown]
# # histogram

# %%
h1 =np.random.normal(170,10,250)
plt.hist(h1)
# Out:
# (array([ 6.,  4., 22., 30., 44., 40., 44., 35., 18.,  7.]),
#  array([144.70200234, 149.42183939, 154.14167645, 158.8615135 ,
#         163.58135056, 168.30118761, 173.02102467, 177.74086172,
#         182.46069878, 187.18053583, 191.90037289]),
#  <BarContainer object of 10 artists>)

# %%
# function  random.normal(loc , scale , size) loc = mean , sacle = standard distribution , size = shape
